# %% [markdown]
# <a href="https://colab.research.google.com/github/riteshTelkar28/Machine-Learning-lab/blob/main/ANN_with_CIFAR_100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing libraries tensorflow,pandas and Matplotlib**

# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='whitegrid', context = 'paper', font = 'Georgia')

# %% [markdown]
# **Loading the dataset**

# %%
(X_train,Y_train),(x_test,y_test) = keras.datasets.cifar100.load_data(label_mode="fine")
# Out:
# ...
# 169001437/169001437 [==============================] - 4s 0us/step

# %% [markdown]
# **Getting General idea of datasets**

# %%
print(f'The shape of X_train is :{X_train.shape}','\t',f'The shape of Y_train is :{Y_train.shape}','\n',
     f'The shape of X_test is :{x_test.shape}','\t',f'The shape of y_test is :{y_test.shape}')
# Out:
# The shape of X_train is :(50000, 32, 32, 3) 	 The shape of Y_train is :(50000, 1)
#  The shape of X_test is :(10000, 32, 32, 3) 	 The shape of y_test is :(10000, 1)

# %% [markdown]
# **Scaling the datasets**

# %%
X_train_scaled = X_train/255
x_test_scaled = x_test/255

# %% [markdown]
# **data Visualization**

# %%
for i in range(12):
    plt.subplot(3,4,i+1)
    plt.imshow(X_train[i])
    plt.axis('off')
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Georgia' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Georgia' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Georgia' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Georgia' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Georgia' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Georgia' not found.

# %% [markdown]
# **Building simple ANN**

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape = (32,32,3)),
    keras.layers.Dense(3000,activation = 'relu'),
    keras.layers.Dense(3000,activation = 'tanh'),
    keras.layers.Dense(3000,activation = 'sigmoid')

])

model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
)

model.fit(X_train_scaled,Y_train, epochs = 1)
# Out:
# 1563/1563 [==============================] - 1063s 679ms/step - loss: 5.8765 - accuracy: 0.0106
